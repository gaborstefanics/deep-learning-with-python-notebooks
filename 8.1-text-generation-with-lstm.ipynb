# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.4'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length: 600901

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# WARNING:tensorflow:From C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/1
# 200281/200281 [==============================] - 398s 2ms/step - loss: 1.9553
# --- Generating with seed: " physical man."[19] this
# dictum, grown hard and cutting bene"
# ------ temperature: 0.2
#  physical man."[19] this
# dictum, grown hard and cutting beness of the consciences of the soul of the consciences of the moral the consciences of the consciences of the soul of the soul of the soul of the in the soul of the still and and and the still the greater the consciences of the man and the own and and and the consciences of the consciences of the some has of the consciences of the soul and and one and and the soul of the and and the still the deligh
# ------ temperature: 0.5
# and one and and the soul of the and and the still the delight to be apon of the desired" and sould profornd, the enture of the moral the or good
# the conduries is all the expresion, of the religions and opposient of the gowne, the whole they a deligure of such and all be a proficence and a presined of phenomans, be and the more in the consciences and still of the one of the
# relogior the one and so genent and in the soul of the greaten of condiviration of ou
# ------ temperature: 1.0
# genent and in the soul of the greaten of condiviration of our opliable,
# relation of longs on,
# deligion caos. who sense they
# the dorared
# a delocmivenceing aloked
# sarionations of the sen on, goow" one coussional, ippady, as that, in fir the da, it to be precidinct wit ot slord=--aud fearner, are
# id: he silf-shooly
# commains the or the sgronge, of somat, theundion. he consraar fremuct, for a beants wathys the ager, traned defren she weors of resolly the sen of
# ------ temperature: 1.2
# thys the ager, traned defren she weors of resolly the sen of greatenge-deliance, woll
# one, powin 7free, been fliesss, undustly for  the viede not if "lovelan innou stand
# exumously cruce o)
# feround alteed",-is didishly, noure ambendhationralat philosopht(obcesjow," deally with to
# roubits of accivulesily lunst oil flond, onul to a bege,
# ivani" ard, entlem, of inviffication, and clunatipl, the in
# the dryo) sose 1houth dos pain of repulst sorevinggely feing ev
# epoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 378s 2ms/step - loss: 1.6177
# --- Generating with seed: "ts of surviving truths) can easily become so great
# (as, for "
# ------ temperature: 0.2
# ts of surviving truths) can easily become so great
# (as, for the existence to the suffect to a man is the suffects the conception which he who are the conception of the see he who has a self which he words to a concerning and the self confect to a words of the suffects of the streteration to himself to the suffect of the suffects the self contempt the suffects the spiritual some of the same the suffect to the such a stand the self confection of the self a s
# ------ temperature: 0.5
# fect to the such a stand the self confection of the self a spiritual freeding estimate the explained to some his of a means for a means with the sinching concent to the sensition of the state of the trued, and problem to the whole a with the former to the well and for all the truth of helpt of the different of the sufflect, and consequently and the suffect of all the seris the perhaps the chereation which he will nowly of the life, as words that the frecti
# ------ temperature: 1.0
# on which he will nowly of the life, as words that the frection of cmet insciented, however calor appuch opined,
# stupits
# to religion is not concoman artive dreaths,, the called.
#  retain its, kndmonstility to formed chance of mironong, to polonty" for nowly of
# whiched the
# refermmate heirs, fthe origin brought, in the self of the
# suce bat whome -theyshand to selirous which noin is state, anty to at compein the cacronuce of its dumiliture and from it solf an a
# ------ temperature: 1.2
# ompein the cacronuce of its dumiliture and from it solf an antemors
# very prom that is new caser all clads spire onk for her ,ime
# and criationation of
# who nencian bad, ebel. will light along rationfol bit which an ther"atiancen who the divelment" and yton to sepain of
# conlection--thems"
# and procoportwy's by
# suffluttiky), the comprshoprdain at onic well-wumanr
# alternestion, it
# ?t' the hethilan. thoughquibal crespitution, at and tpoarnquise of
# his hapselogop
# epoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 393s 2ms/step - loss: 1.5345
# --- Generating with seed: "his nature, nor his motives, nor his [course of]
# conduct nor"
# ------ temperature: 0.2
# his nature, nor his motives, nor his [course of]
# conduct nor in the spirit the spirit the spirit of the struct not and also the spirit the self--the last and distrustice that the spirit the spirit the spirit to the spirit the spirit to the spirit and disconternal to have the exception that the sense of the spirit the spirit the some one the more and present the spirit and content the content and still to the spirit that the spirit and reself to the spirit
# ------ temperature: 0.5
# till to the spirit that the spirit and reself to the spirit and philosophy and precisely and as all for the self--is spirit in the spirit that the stating the instance. the really the spirit to the will to one greated, and the intellectually, therefore, as it is prevalled. resenting man, and latter become freedom the courte which no relations. the end for a indecepal that is it is religiously in the
# invalues and spirit causing to have for the experie in vi
# ------ temperature: 1.0
# he
# invalues and spirit causing to have for the experie in virtue he same ratinn, or no longer of
# postible. but what the case there is, "from once has reidence and properatic speake before
# view not--that the pir, to yet, the great
# velunated to the semicipisiy and mor contrary the degreques
# alvast" treasy of
# the forcient, he who knows co says who zach in them, but tirawr--it woubhus upon their consid even
# the instinct this relatide brong is change of greatt,
# ------ temperature: 1.2
# d even
# the instinct this relatide brong is change of greatt," fraceborifods of of difficuric (makitraficked?--
# "wouldds, as not  ily. the "freedomed he mataing
# ame dranusting, when he
# it" to spe for simgnesther is
# what doubt--decurty "a use, sucerosing
# senoungroudsed, altin-grall is processarouresss will c
# moxenty,
# on hi
# speclting
# as antisu unimpok:
# have thou greated of a pessiaurring
# that all a
# queeningsibue and not not consciousnism: in distien naturati
# epoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 428s 2ms/step - loss: 1.4930
# --- Generating with seed: "nd painted thoughts, for
# which alone i have colours, many co"
# ------ temperature: 0.2
# nd painted thoughts, for
# which alone i have colours, many communical to the stronger to the sufficiently and the prient of the stronger of the stronger of the spirit with the same only the spirit of the suffering the spirit and supporine of the same to the stronger of the sufficient of the suffering of the stronger and the species and the stronger of the most soul the spirit of the most in a distrust and the more intellect the spirit with the commons of th
# ------ temperature: 0.5
# ust and the more intellect the spirit with the commons of the being and power of the sense in the work is present interpretardent of manking in the heart of feel as and opposite in the same as the bast and man indeed with the
# overthe opinion, and the suffering and them to the simplained of the truth and and commoning, the sentiment to consciole to the most for the complicated to who knowledge, and in an endurish and stronger of he and create compared, wher
# ------ temperature: 1.0
#  in an endurish and stronger of he and create compared, where manking, st themselves manows to mags as litenioned of philosophicing of miscrong
# complient fow phred imperway re rous command times--bading to theil one is "faund must as the posit toward, are the highest vistous elequence of the evilw man serenic right is complaik, in out. that even reabons greatest sup
# faws, possible, him. to be
# poster, is defanges he wishous becomes of once of pute or a gett
# ------ temperature: 1.2
# er, is defanges he wishous becomes of once of pute or a gettest gree pusion of them newis .. wishoutsorially ma
# tafter and that,
# make anything myst
# ideas,
# than it?--  ", and enstine wo deselvas,d rga
#  .
#
#
#
# this hand difinons--it
# not
# a besein conmpontenwler, such inconquraquted it, we misuxflinical disexe sare areiably in
# misunderstand the refsenting most belose without theur--for his inbicy," howe--causs: wat does nothieg, inalchious, sensual.--for exhpis
# epoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 438s 2ms/step - loss: 1.4644
# --- Generating with seed: "en constructed
# yesterday and today; there is perhaps some sl"
# ------ temperature: 0.2
# en constructed
# yesterday and today; there is perhaps some slaveristic and the problem of the soul and and not the spirit and the statists of the subtertic and and the spirit of the expected to the suffering which is and and and soul and the moral conscience of the conscience of the spirit of the spirit of the sufferent of the soul, and the moral to the soul, and the spirit of the soul, and the spirit of the sunderstands and the state of the suffering which
# ------ temperature: 0.5
# rit of the sunderstands and the state of the suffering which wanter to an interesting in a consider of the most soul of morality, and which contemply and abid to the
# possible of the desire our only a pain is not in an inspired in a contrain still praces
# of the compretent of himself the tarted of the science of the learne and still so that it so influence of the particlation and intellectual when not entile with one conscience which has have only always for
# ------ temperature: 1.0
# ot entile with one conscience which has have only always for accountr other and difficult of fingly becoll-possegrously, and the bannounes, to bolllded. such a significanarid, "socred problem of dour languaged to one graw oel musicy and althodness of here that to see so can be shortuneous and way they not the splase untigning will in reging of philosopher power, is "lives (in trove prectionar, as i capactions ta--the dring its from a most rage" may aust of
# ------ temperature: 1.2
# i capactions ta--the dring its from a most rage" may aust of h-namen want frogrer, and coam inseasien, is magining the lake time that allejoop, alonk yes sunhrumance of
# the mpoph you supreah notion and rights herder
# whaurs essentisxilatiwle standent
# and whoely net the
# dangering them. when iws hower. he
# grance, and furcion, ow, concean ditorate--heurist
# has its salg. whatly to his
# easis--a obse just vigirition, are ever and uncrinors w-the untad-elscies ch
# epoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 527s 3ms/step - loss: 1.4442
# --- Generating with seed: "is own salvation; when, for example, he builds a
# church or a"
# ------ temperature: 0.2
# is own salvation; when, for example, he builds a
# church or an interest the specially and the consequently and the spirit of the same to the subjert of the sureing of the consequently and the consequent to the souls of the sures and the self--the commands the such a really be as the souls of the sentiment of the same the such a states of the consequently and the sure of the sure of the world of the soul is the souls of the sureing to the states of the same
# ------ temperature: 0.5
#  soul is the souls of the sureing to the states of the same by the consequently be the saight of a pererate will as it is the impurately to its approped it is will reading, in the do evil. he who have been interesting of the some period not it antiture and consequent to the compled, and operations
# of the something and the spiritual consequent with regards too grates of the romanticially
# it to be so profess of the brought and the faith of the ordinate in th
# ------ temperature: 1.0
# o profess of the brought and the faith of the ordinate in the unity and reark do a happety. at i yeugfou
# things; the word conferslise and
# more "brapated philosophess so langvahe--of their understand; a padie is he easiesterbaring  without knows whe refiren u1"own convent, cail, we human by owe wart too
# voluing, ries.--"""among is almost allowy, with a day is a by at encions of the fast. nocespbeiness, of an enty have reark of the earth have be pad creable
# ------ temperature: 1.2
# ess, of an enty have reark of the earth have be pad creable harronlay
# too mch!t contedored it
# has how only will
# himself enteme able to ressitute orgainting, to mygoisuovy insenderation--fill i castess." at this .or",
# as from the marrauctes" must see some betrays, placesd it , to hiddualisesdapxying age, alt effeses of that speak secures caltingt
# a strubat more worldureossed filmosess, for they
# sude, shiuedmenlation. who, was no
# msalm betimes far ounce have
# epoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 584s 3ms/step - loss: 1.4294
# --- Generating with seed: "he finds so
# displeasing in himself. to feel himself more unr"
# ------ temperature: 0.2
# he finds so
# displeasing in himself. to feel himself more unreally to the sentiments of the complence of the same to the feeling and distrusting embrase and sentiments of the sentiments of the sentiments of the fact the compledent and sentiments of the spirit and problem of the spirit and the spirit for the state of the spirit as the spirit the sentiments of the compare of the spirit as the sentiments of the spirit of the same to the spirit of the most man
# ------ temperature: 0.5
# nts of the spirit of the same to the spirit of the most man and destilusion and power of the "freents in the subjection the best self-contrary stand and man in the sacrifice, the
# spirit of the problem that they all conside he general contrary and grasply of its european and discovere and but there is in the man and refined and being but contrary not reason and mistaken in the free taster and also the fire unwill to the one compleariation, such and never as
# ------ temperature: 1.0
# the fire unwill to the one compleariation, such and never assute refearation ner,
# himself depths. which man are "of
# weachar ofly of leg the does
# still yeafle the
# xor in uncornstiones with who politeplets, or which proved in bad many to reing owsak of simpility" afaarour, away of a taceed alshome, if sound) into longlegl"!--many selfy spirit from "accountary bring and braums timefulness--the
# opporified away in the
# philosophers for iditable in this soul as i
# ------ temperature: 1.2
# fied away in the
# philosophers for iditable in this soul as inextersal, wish, great
# physicaluclavy god to
# lim friedious emgeaulation. in aupotionary yeally slald
# go, this pointent-assemrical goided peechanded and
# nihurmanily, perualirmed
# be(fortm? in the problem and evidence of badwhather
# offrrie
# of
# hust rather
# bad categu; any
# ats itmentine will conside whatever bad boevss firetly
# the simitate thought: he disporri, many cluea sknolleding materition apud pri
# epoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 678s 3ms/step - loss: 1.4150
# --- Generating with seed: "cient world,
# which fell upon the christian peoples, the shad"
# ------ temperature: 0.2
# cient world,
# which fell upon the christian peoples, the shad the sense of the consideration and sense of the most still the sense of the soul is the problem of the sense of the stroke the soul, and the sense of the particisal consideration of the sense of the most still the sense of the present the distinction of the standard and delicate the sense in the most still the complete and delicate and desires and decided and and the sense of the problem of the s
# ------ temperature: 0.5
# esires and decided and and the sense of the problem of the saint which the comment and commenance of the ease the greatese man we consideration, and soul and the position and the difficult to please of the ethics which is not as the same the present that as a the father and former because of the world of the reason the inclusions the strength with the heart be and the commendance, and has been excertion is instinct, the complien personal consideration the
# ------ temperature: 1.0
# ertion is instinct, the complien personal consideration the noble-drem of only the from here imincless ever a clised in this.wjessenes for individad," that wrets relaon, one may mabanter, as mention, appronces loves doett (commany dong in as the rema jay the world, and
# fore, and power, the that lang!--but a special guese itself himself,
# and in averinction, the wholen,
# but what sang pand of
# science, amginate,
# it may see,
# there is a langshis. society of the
# ------ temperature: 1.2
# , amginate,
# it may see,
# there is a langshis. society of the act of without
# decidenous modoud, unders of ention
# to have by merise just of
# anylly, to envoor;
#      ooune is at a dilis, ordinary live.
#
# us
# "by  ii nothing very doldpecsiity vainble endchilic even owing all secuudr, to respecioning spirits" underyokas in also could feluser in ordinaryul,gences, doath, refre, weareles after keep "swe virtely as "la, dhe od,
# from seems
# that really beliect, even ot
# epoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 303s 2ms/step - loss: 1.4045
# --- Generating with seed: " unrestful joy to long, to lurk, to hark!
#      i peer for fr"
# ------ temperature: 0.2
#  unrestful joy to long, to lurk, to hark!
#      i peer for free still the commands to the science of the same different to the spirit of the same demand to be the spirit of the distinction of the same different the strength of the same discovered that the good and something the more the suffering the the same only the domain of the spirit of the same different and something the subject of the same different to the spirit of the more and the subject of the c
# ------ temperature: 0.5
# different to the spirit of the more and the subject of the charm and personm at the indifference to all the cause of the far, the
# wards, the germans with the suffering in it, not been with made a possessions up of the artave he is therefore, what the suffering must
# be long and sign it is does not the religious condition and thinks which it was a destruction
# real to the here estimates, one ashom, and there is does not be the soul in the same strange in the
# ------ temperature: 1.0
# nd there is does not be the soul in the same strange in the stromed a persuapm and
# loner that he had not chomtinch,
# with a houls, "conscience; for found, eithest as thee disgust" something serers
# of time a impost stateie, and dedication of the certain
# completeonning a faith are
# inners the unidentaneses in relation for godgued
# to af the read--when present one glow andeness, hands. the extraorder pherited concegnce (bece-doked who
# modern tune lar, socitty to
# ------ temperature: 1.2
# erited concegnce (bece-doked who
# modern tune lar, socitty toow with their same stitulary rown dedations of phent of a body, times of view more: gate religiously-day in anothing if one for thavow, condition. therone short of folce,
# but of who wise dypose it would bal, as setanss toiblection to no truth, and only only differently: syithies-.n-punds afordines:
# everything, that have: "judgmates
# the can which
# lass-gradiate cleaked in unothesse, now upon anothe
# epoch 10
# Epoch 1/1
# 200281/200281 [==============================] - 336s 2ms/step - loss: 1.3945
# --- Generating with seed: "
# although not yet forgotten music. this whole music of roman"
# ------ temperature: 0.2
#
# although not yet forgotten music. this whole music of romanticious and the contempt of the spirit is a spirit of the same different the most sentiments of the sentiments of the stranger, and the spirit of the spirit and the soul and the distrust of the spirit and the sentiments of the sentiments of the sentiments of the suffering the sentiments of the sentiments of the spirit and sense of the sentiments of the sentiments of the most soul is in the sentime
# ------ temperature: 0.5
# timents of the sentiments of the most soul is in the sentiments of the prompterness of the soul speaker of the called being under the philosopher be the world of german than an eneminates to the part in the respects of the pain it of in any organing and in the suffering of the same than the individual in the fact that is an assument the pain because man is always the distrust of the artist the sentenity and fortunately as above an admiting of the consequen
# ------ temperature: 1.0
# tenity and fortunately as above an admiting of the consequently it, in sleeps of a comparence--causations, only why cleims that the grandwith" hand-ord either and oter at alike themselves, like and concented. that is like possioned modoury who is an intain a
# man deet tlaes tleden at it has bounder from sympathy minds
# intelleating may slalshe--the extempt, and in the lightly
# not infect the beings, hence of expuliois of which the fimstuce of themselves.
# theo
# ------ temperature: 1.2
# hence of expuliois of which the fimstuce of themselves.
# theody ref-right to the know.
#
#   admoreure great sacrifice krow wonn contestizubility, with operve it is exhest of the spirit what worthy must, howe. but "uncomlefuce puppating
# philvel to ne to ough
# us simoasing
# tounge-prreating the mowne-the finot for tice day to clendvez g, the spirits onergain, punishm of punish of absolute
# petty feel pervevsed of hardous
# in world, benfitural
# with beene--and sense
# epoch 11
# Epoch 1/1
# 200281/200281 [==============================] - 359s 2ms/step - loss: 1.3868
# --- Generating with seed: "g to the thought he expresses, or which i believe to
# be evok"
# ------ temperature: 0.2
# g to the thought he expresses, or which i believe to
# be evokien in the man is always the spirit the fact the most speak of the supposition of the same to be stronger in the most the spirit is the spirit and the spirit and stronger of the most the succession of the same the subject of the supposition of the most succession of the supposition of the spirit is also the same taken in the spirit of the success, and the strength of a perhaps always the fact a di
# ------ temperature: 0.5
#  success, and the strength of a perhaps always the fact a discovered and advanntant a thing of the intellectually as the most beginnity and self-strangually to endicess and dangerous honour, when the same mind would perhaps the dangerous seeming the most will to the discovered out all most way, the recogning pleasure of prosely in the profound, and in the pries and with the supposition of a pood all the free the science is betrayed to requiring of the most
# ------ temperature: 1.0
# ll the free the science is betrayed to requiring of the most seemed without for those man is a noble conditions, thereby thoughts in action and exusists, far the sense of his "acception of the simple, too preason dymous, namely habit to brisfesin will desistness," and strongundkiner woothrass),e(goved upon woman or independence, which has the great dlyiling
# evenmued, the reasons, how opening of
# question they having as although in hirsely evil and believed
# ------ temperature: 1.2
# estion they having as although in hirsely evil and believed conig, to bupoul there is mean will mvoval generate the aremande tendi understoly--for a ne; only is
# unpemon leave for eyes"fie, wquil, misteque warnty in which on their woed of all selure clace--on
# geinated view o riict; it does be conformapless in means, and boralism, lokes, timitly the kind. deliobmoned,--possessence to creatualisi "unch? but wemons perusus, i things upous genessable breaker a
# epoch 12
# Epoch 1/1
# 200281/200281 [==============================] - 382s 2ms/step - loss: 1.3784
# --- Generating with seed: "in justice. hence one must say "the wise man
# praises not bec"
# ------ temperature: 0.2
# in justice. hence one must say "the wise man
# praises not become who has been the free spirits, and the sense of the common and the spirit and the said the common and the problem of the common the more intellect and in the spirit of the conscience of the common the act of the spirit without the said the continuent the desires of the same deceive the feelings the religious the faith of the desire to say the said as the said the master in the same deceive the
# ------ temperature: 0.5
#  say the said as the said the master in the same deceive the good of the free must our for in the whole of his comperis in the master of the said to his most we last desereness, as stand the intellect such perhaps a man is it is a should a most life is the the person of the child may be which every learn stand of the basis of the sacrifice and is long to be succession of the sense of life of condition, who has the act weaker extent, no longer contrasting t
# ------ temperature: 1.0
# tion, who has the act weaker extent, no longer contrasting toy yen slake for the depestimans the nihy-man, hedeag, and master is may be man has foundaily e-refines sure of order to its. we decurem seriously with musians is i made to etrology, and laher one regard more is
# neverthe--good their truit, for the requite this dopted their most still he course of heart
# punt all mad). in still act feel between his view were of then opporance entrective
# cives is dec
# ------ temperature: 1.2
# ween his view were of then opporance entrective
# cives is decholly, mustw!anygat ideal by
# history: wet
# advinment,
# consusporturing bafolers. fiousn, musicisy)-i! idider-fire his ething, the houritt-is my other fransis and
# llar philosopher, no youncing intimials; but
# letomlica
# art them get on
# cridy as asshil
# -partfule
# and may bhinker rriate forming, put of the bisd: without and be but larce or
# piriatour-ed aim benewomany
# made careforthing
# succe of his
# tased a
# epoch 13
# Epoch 1/1
# 200281/200281 [==============================] - 408s 2ms/step - loss: 1.3709
# --- Generating with seed: "se neath this pine,
#      or a plane-tree's broad umbrage, qu"
# ------ temperature: 0.2
# se neath this pine,
#      or a plane-tree's broad umbrage, question of the same deeptine the same the spirit when he who have not the said to the super of the same the successait of the such a perhaps the such a personal present to the sense of the said of the said a things and the subject the spirit is the said in the subject the spirit is the said to the such a personal still the supernation of the such an extent the subject the same the said to the such
# ------ temperature: 0.5
# he such an extent the subject the same the said to the such a heart way, the repussion of the sense of his successually be time the states of the same
# man, where not the states of knowleddity, which sacrifice and sense of the man think of his subject their disconsed the power and spirit when the heart of the word one may be discorrow the same to the serious with the best the suffering and the same the same degree eviden disconsed things the same and specti
# ------ temperature: 1.0
#  the same degree eviden disconsed things the same and spectities in the laister of theereble nobody, to seed being the by the dem ness" a lice the were e contempt and aid,
# but whol.
#  a distingutess
# of truth those unremoter-inclodid in otheoun
# cry delightness of the raral the fausation of  of view and teot not respect--ethicg of have limitart many logic spirits into the u germany of more limate still
# stoll fall physioly--of anoth intertal law, from forest:
# ------ temperature: 1.2
# ll
# stoll fall physioly--of anoth intertal law, from forest: that "not and epet
# avt howeve would is possessirgle seek, who in hingens
# childer into from might
# exceptions and getmable that es for himselves
# mess offfrely. unendly, might ene, throuth of
# metaphy he hongicieg was love sunotness of be
# pain, a manly he senoladising, and other to so
# which, we are
# thin obedxisx--in our thould--hore away.--falments at the deumonss, wonas
# oo the worrn and
# about expicy
# epoch 14
# Epoch 1/1
# 200281/200281 [==============================] - 438s 2ms/step - loss: 1.3683
# --- Generating with seed: "e estimated by our standard. for in that period the instinct"
# ------ temperature: 0.2
# e estimated by our standard. for in that period the instinct to be a sense of the succers, and the succers of the same and the sense of the succers and sense of the spirit and conscience of the same and such and such a these in the same and the same and the same and sense of the same and sense of the succers of the succers of the end and such a master in the sense of the spirits in the same and the spirits of the same and such a sense of the succers of the
# ------ temperature: 0.5
# e spirits of the same and such a sense of the succers of the same there the lost of the spirit was not the proved to the world into the experience of the such its very minds they sense of elevate when it is not instinct enough is the more too all they are operated in the most most something in the sense, the first and that all the praise and interpretation of one and indeed, in the life and losing and soul in the more conscience they developed and who they
# ------ temperature: 1.0
#  and soul in the more conscience they developed and who they have once of life know and trread contemative that  her is list on the enough and sumist by else of "senoming of
# lifey in attermanf which only believes and through mhagnerwart, the act and in plaisle higher
# act
# of profounded her profoundessumes his cured, not possibility, must not at one is mithly.
#
#
# 19ten they is difficult at man of
# imporiate, and there are a deal
# very ecclingm of
# the man of ver
# ------ temperature: 1.2
# oriate, and there are a deal
# very ecclingm of
# the man of veryerlg with their verbes
# scsen, what itself esras
# frat men ampectly forcet, so, of that all epender for everyone,
# like they art
# and ham scomeditte arguly. though those hege, and lessester
# or "pyes
# mo
# buct
# qualitia only icpassilest arms demanedy betgened to in; est" "too
# opienting rank and wably they -which there he in)llandord opinionaker sucaquious, almeen a renogive are stiplom mirfuln, of "thes
# epoch 15
# Epoch 1/1
# 200281/200281 [==============================] - 463s 2ms/step - loss: 1.3609
# --- Generating with seed: "t yet distinguish
# between "finding" and "inventing"! above a"
# ------ temperature: 0.2
# t yet distinguish
# between "finding" and "inventing"! above all the strong and the spirit which is the spirit and the spirit and the spirit and the spirit and its spirit and the strong to the spirit would not persitally to so contrary to the spirit and the instincts and the spirit and in the spirit and the conscious of the spirit and the super-is the strong and the spirit, and the comparing to the such a thing and the most most still the spirit, and the sam
# ------ temperature: 0.5
# such a thing and the most most still the spirit, and the same to his laws of the sounds have been extent themselves the spirit with the strong as all happiness, the
# sporting and
# as is the hards and to the same them is not the feelings of the world and the love and the same other as its artist also not as a metaphysic school as a sturistive which is the actions and the first of the most presence for the world of the
# spirit, of such grow be any one is in con
# ------ temperature: 1.0
# r the world of the
# spirit, of such grow be any one is in constince outrate, grantubeless of truth so a truthment and vest so dangerous play sich with amid reconlection-invalace us, or when but it too had to all which have to his far nowadance,
# with the elstodd as
# me that the arrolance of all oppnin" essycal, as a self--in
# an ressard odermanden does not and them." depling it want no logity which has to
# its achome refe some distrustful," the work or not euro
# ------ temperature: 1.2
# s to
# its achome refe some distrustful," the work or not europe and tyye: of trouble inequancy penil into the creass.=-"as which its grawe that
# is latest a greatness
# of "man-and
# agness, through sygh of bearidly, to had toad ought and seeds for
# others form
# an admiry over, by the
# mind themselves virgious distast.-
#
# o nowadatical sentixy free literc--gree discovere, and for the expority on whese
# subsecroment. here, "
# revoestologi worldele--what
# as passions wis
# epoch 16
# Epoch 1/1
# 200281/200281 [==============================] - 478s 2ms/step - loss: 1.3551
# --- Generating with seed: " to be approved of; he passes the judgment: "what is
# injurio"
# ------ temperature: 0.2
#  to be approved of; he passes the judgment: "what is
# injurion of the saint of the soul the saint of the standard of the superficialisis of the standard of the saint of the consequence, and the special the saint of the sameness of the subject of the saint of the strength of the sameness of the saint of the sameness of the spiritual to the standard and the states of the saint of the sameness, and the samenes himself to the saints in the standard of the spiri
# ------ temperature: 0.5
# e samenes himself to the saints in the standard of the spirit of the strengthing and religious in the influence, and dispropers of his promised
# in the sronge the sameness, and who will in the strength. in the distrust of the house in the antical intellect in the saints and remained and science of himself that he deceivers, he more conscience in the sameness and consequences, in the
# belief of men, all in the extravales believed the masters for the but the m
# ------ temperature: 1.0
# all in the extravales believed the masters for the but the myinified
# think and the trimines premaint merely and of
# this sysion, those from the physions to us anything purpothor, alloim explaining rogies,
# force, and the
# sappy gallent, of
# every view valuaits--his conditions now a sonts at discovered ower iftenss, of inumprospecation and men! and laith is a thing of accesson incear faith in means, europeant. indeedge hir--as so contined
# of conditioning by att
# ------ temperature: 1.2
# ropeant. indeedge hir--as so contined
# of conditioning by att",
# lifible; the minds
# ipeaty of thith. if where so at anyardily.(
# conoition of always at doors; that tait, some over.b!
# perhaps,
# be mistaken and
# way, origists for it from ehilness, philosopht alload to the belief of prochering,
# man, the oul
# carn, for that of herm their conschomans which
# ancient slav-be as lands
# grously being
# carueg
# exceptioun
# and ocfse
# being them-andum anxi" and
# visceness off soli
# epoch 17
# Epoch 1/1
# 200281/200281 [==============================] - 500s 2ms/step - loss: 1.3511
# --- Generating with seed: "d the next world, where in that period everyone thought he s"
# ------ temperature: 0.2
# d the next world, where in that period everyone thought he strong to the trained to the spirit of the spirit of the spirit is all the present decided to the spirit of the spirit of the spirit of the spirit of the spirit and the spirit of the spirit and the spirit of the said a more and the world in the spirit of the spirit of the spirit and who has a fact the contemptation of the spirit of the highest the consequent of t
# C:\Users\gaborstefanics\Anaconda3\envs\TensorFlow\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# he spirit of the spirit of the spiri
# ------ temperature: 0.5
# hest the consequent of the spirit of the spirit of the spirit of the bad a there he we consist of the profound still to be interesting to an attentation and spring that which is the spirit of the hands in the subjects and the contemptation of the world be standing of the case the spring to men at once of sense of the decided to sentiments of the new and spirits of which the probable the dangerous
# spirit of personality and always from the spirits, where als
# ------ temperature: 1.0
# spirit of personality and always from the spirits, where also a spirit enlict and nevery ourselves in the logical fine the fintnes"" to trotts condicion! strong-intellectuancy of the
# looking
# il talk for the untranotic, in one's parsiosing and to the recare civque of one enter do won a side. the wear, in moral course, and question of -who is present instingh is without
# high and abstanday
# in letpe of the teres; power reself to thew above at rise comprehendin
# ------ temperature: 1.2
# f the teres; power reself to thew above at rise comprehendine-rightly mistimonshing valuaa(lass, for good to the famins this "move.orable underdotwquict believe of give
# that -what religious who  thand-certain may rud very have be
# equally bermel ofe. really sa, "modes belief vical
# new delight,
# ?x in the fouctlition and non-actions though" definite pullly laid pulists amvebly whreseal,"
# the presumbl out
# of the press onwaw listerven ele"efrs, suhincning of rr
# epoch 18
# Epoch 1/1
# 200281/200281 [==============================] - 822s 4ms/step - loss: 1.3476
# --- Generating with seed: "ns (in fact better than under
# favourable ones), by means of "
# ------ temperature: 0.2
# ns (in fact better than under
# favourable ones), by means of the spirit with the spirit is the spirit has a still the such a think, and in the spirit and such a matter with the spirit and sense of the spirit with the spirit is also the instincts of the spirit and the spirit and strength of the such a prompt thereby the strength of the spirit, and a still the spirit, and for the same desire the suffering of the such a person thereby a still instincts of the
# ------ temperature: 0.5
# ering of the such a person thereby a still instincts of the present time we realment to be such a matter the brings and artistic the can decressions the fience of evil. and the means the colont in the art
# itself we has a soul the probably been prevails and consideration of and such a connect for the conduct and russ to be assumptive and every instincts and strength of single the excession dive and eager in the spirit
# are really interpentations of the part
# ------ temperature: 1.0
#  eager in the spirit
# are really interpentations of the part of
# fruch a assylemgy of has been superficial of the posse" emotherlenoritys; indeed they clangts for his
# and upan sensevenunfoment
# has the test some otpels--of inscriocs," why
# conmest inability, firminality. it were, it has say, as under the enfience to
# dies--which have its and great moral,
# present conduct range how him, markes batt
# in its
# justice with regien, and lett
# to an
# referre, and
# philosop
# ------ temperature: 1.2
# ts
# justice with regien, and lett
# to an
# referre, and
# philosophers alone, to estfmy funist, but as he vi, ventbones testiment: as he saids bein.
#
# 141.
# the time he state, bein:
# "complanced fyowno in the science, for ord controle that our right for
# throly desire render now else's language, not must-
#   okener instinct and ne: our pateceful of the sensition"; he is her analyd
# interpertnes, that this europeally, rather this
# disne, man--her, he folr e.t to their
# :
# epoch 19
# Epoch 1/1
# 200281/200281 [==============================] - 1152s 6ms/step - loss: 1.3426
# --- Generating with seed: "world-exposition and world-arrangement (according
# to us, if "
# ------ temperature: 0.2
# world-exposition and world-arrangement (according
# to us, if it is the spirit will the souls. the spirit with the famility of the souls.
#
# 181.lquce to the spirit and the stronger and the stroke the strength of the contrary in the spirit is all the same to a still have the religious spirit is the spirit with the same to the consciences of the same to say is the same consciences and seem of the world and the most who are the same to the state of the spirit wi
# ------ temperature: 0.5
#  and the most who are the same to the state of the spirit will to an in reserve and in mind who is to say would be comparable to see the mev" our to the age and be graduction to
# the such the consequence of a man and what i be spiritual aney connection and the supernation and suncented in our evil is all the stroke as a good in short, it is the contemplation,
# one for the strength to far the sense, and in the world and intellectsal experience of the spirit i
# ------ temperature: 1.0
# and in the world and intellectsal experience of the spirit in the beutild in prused.t i look so
# instraances and actions
# the "deceptation be them hand," or in yething something is extent and bad--for the sensely reluine to
# use
# taking inloping to he would alwave be donurly
# of
# spiritune! and in swork of a wordly
# find which is friends
# moves, as, more.
# the inside of day tyest of "begins and depth of
# actions of all rase,
# against for the most he fearn be wounds h
# ------ temperature: 1.2
# tions of all rase,
# against for the most he fearn be wounds hardomolour etrved
# the operates
# him.
# the regarded (he ?que chrimle
# inbored and moin selfest: "i nuch buculueary to
# mind.--ireackoriously
# avaritesty anous
# exercised, esserring, little use that sense horther and thinking, mustche of
# one his kyses towardtjesical, re.ood with more
# needs
# ajvaleable,
# and who canepor ch to had to felt owly were inaumes habitual efficerness itselflybchy istempterable inmer
# epoch 20
# Epoch 1/1
# 200281/200281 [==============================] - 1203s 6ms/step - loss: 1.3389
# --- Generating with seed: "nic functions. "exploitation" does not belong to a
# depraved,"
# ------ temperature: 0.2
# nic functions. "exploitation" does not belong to a
# depraved, and the sensus highest the spirit, the spirit, and which is the subject and most desires the spirit, and the soul and the state of the superiority of the such a philosophers the sense of the spirit, and the spirit, and the spirit, and the spirit is the spirit to such as the spirit to the spirit, and such a still the superiority of the contrary of the suivours and such a stronger such and the sure
# ------ temperature: 0.5
# ntrary of the suivours and such a stronger such and the sured and diselevated the profound to be at the same spirit, and it was such a longers and such as an experience, contrawic formerly and delight to its degree the sensu deduction of the development, and not as the sensible and suivers and the desires in the spirit and good a spirit, and in the spirit only itself with subject and and great demand, the soul the concealing for the heart to so into the su
# ------ temperature: 1.0
# and, the soul the concealing for the heart to so into the such a teasy inedeastable longible a
# lister. then
# been faculties of manter, and the case
# which rechanges with trut reste-solition the topet surk and the e alsaking o
# seadud, things that a stribine culuaths, he
# more compulsion as its ard-all understains (in equally them wable
# consideration, but the
# power
# invents practiced acts of a point philosophy, stigman, still perhapsoques, whicg malk
# our philoso
# ------ temperature: 1.2
# losophy, stigman, still perhapsoques, whicg malk
# our philosophers when the timative pet and worthuret,al it threeca; a morals forrarden with its hand creatonity has temperably rexcity of suddels smigogules.=--reculuous friendrmasu.
#
# staitponing, as its veentquion its owwakene-cremated were pittcluan birditosing ous corpotety as enemistic luch (right formousnkers (and
# decoiners)
# at orby with this some"; whoevating basmash-calming
# these offer yeron! the dcom
# epoch 21
# Epoch 1/1
# 200281/200281 [==============================] - 654s 3ms/step - loss: 1.3338
# --- Generating with seed: "e's four virtues, courage,
# insight, sympathy, and solitude. "
# ------ temperature: 0.2
# e's four virtues, courage,
# insight, sympathy, and solitude. the senses of the subject to the same dispart of the same dispart of the suppose it is allowed and common and subject to be so the common a still in the same to the suffering that it is the suppose it is the suppose it is the same to the spiritual the command, and the suppose it is the same success and single and supality of the present does not be such a personality of the suffering the subject o
# ------ temperature: 0.5
# oes not be such a personality of the suffering the subject of a man is has hitherto viridiant, in everything possible be of the higher in the whole person what is the virbus the religious and consequently and suspecimate the truth is a feeling who is now the inferior of the most experience, and wished to the supposition. in the greates from the spirit of the confess a companing with a man seems to the attained to be the world of the pupperism a place of th
# ------ temperature: 1.0
#  the attained to be the world of the pupperism a place of their higher of the secondation of themelves please with "and most suspercay cases, character," what refined to onew his perhaps, a first fear--new more overwquile developing of the depocritical puilamesic.
#
#
# 1131.
# whose sometimnation or "the one has hitherto at in the early, "for "races by virement but beforally fear" we one and peence of convomured of one'st ocbeant to the secrel. or from which
# fr
# ------ temperature: 1.2
# convomured of one'st ocbeant to the secrel. or from which
# from
# the hel more that its
# apple; is
# what into ime! someculation; and eventurious for themodegrue rograticpality. as out only for, helpious venous (bacgming, both fastiently it its eeporated to
# better,
# he who knvastate reable, as filthes.
# is other bestbr-iscessung recivelng whom e prince of all new old if everythin is upticis labout
# has oving callings,
# notor humally beautiful staies shall this indi
# epoch 22
# Epoch 1/1
# 200281/200281 [==============================] - 663s 3ms/step - loss: 1.3321
# --- Generating with seed: "rynx;
# partly on the strength, endurance, and power of the an"
# ------ temperature: 0.2
# rynx;
# partly on the strength, endurance, and power of the ancient seems the world and the conditions and the first to be still one who will be more seems to see the problem of the first and as the religion of the superiority of the same to the father of the first and also the same to really also the constitutes the most morality and superstition of the free spirit is the discolle--which is also the first to merit, and the first and the proper as the most s
# ------ temperature: 0.5
# e first to merit, and the first and the proper as the most say is any one religion the world of the first of the reality and the one to the masts and ancient pain, the spirit the wors of the ears and the world and of the borouses, the conscience,
# conother, as to heart and are error and the praced minds of the supernated as a sort and enough in the sampto a strength still one could opinity of at the communication, and and for the allegents and also opporer
# ------ temperature: 1.0
# e communication, and and for the allegents and also opporer continuodied be a thinked, mitall." and the lupbolwing for domel, arding, cafter: he from these national and
# slowly
# error in, situs they har
# conwilations,--i who have for a responsible that drech, who not be his ratestry
# and naturement only afquired,  funfice; churien only he is now ye delusions of mind has them of the tomy and evil versegmous
# standfulgent,--then thought, which carimatically bring
# ------ temperature: 1.2
# gmous
# standfulgent,--then thought, which carimatically bring that the
# suruatim to regulates, duntly eyess-cruelty.
#
# .. men
# in the most disculnace only of this ways to like the intempors self sunside, cimrct may peasure, let uncoun.s.s of a way, blomething, how savely which to deproh other that seems its grates superforme.
#
#
# 97
#
# "neelcing, the
# lifed emotion. and truth a dien-seels. with a gerwness of
# his seawly
# pourt hundern. which means enlichils, to disgu
# epoch 23
# Epoch 1/1
# 170240/200281 [========================>.....] - ETA: 1:44 - loss: 1.3254

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
